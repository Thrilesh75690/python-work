# %% [markdown]
# <a href="https://colab.research.google.com/github/Thrilesh75690/python-work/blob/main/day2_ipynb_t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#which weather the number  is even or odd?
num=int(input("enter the number:"))
print(num)
print(type(num))
# Out:
# enter the number:40
# 40
# <class 'int'>

# %%
#accept marks from student and display
  #Excelent -- if score is >90
  #good -- if score is b/w
  #below -- fail

# %%
#accept employee basic salary and find gross salary?
basic=int(input("enter the basic salary to find gross salary"))
if basic <= 10000:
    print()  # hra is 75% on basic,DA is 60% on basic
    hra= 70*basic
    da= 60*basic
elif basic <= 20000:
  print()  # hra is 80% on basic,DA is 65% on basic
# Out:
# enter the basic salary to find gross salary8000

# %%
#accept employee basic salary and find gross salary?
basic=int(input("enter the basic salary to find gross salary"))
if basic <=10000:
  hra=(basic/100)*70
  da=(basic/100)*56
elif basic <=20000:
  hra=(basic/100)*73
  da=(basic)*60

# %%
#accept username and password and display
  #  invalid username -- if username is incorrect
   # invalid password -- if password is incorrect
userna,password=input("enter the username and password")

# %%
#accept username and password and display
  #  invalid username -- if username is incorrect
   # invalid password -- if password is incorrect
username=input("enter the username")
password=input("enter the password")
if username=="abc123":
  if password=="thrilesh777":
    print("valid username")
  else:
    print("invalid password")
else:
  print("invalid username")
# Out:
# enter the usernameabc123
# enter the passwordthrilesh777
# valid username

# %%
#accept username and password and display
  #  invalid username -- if username is incorrect
   # invalid password -- if password is incorrect
username=input("enter the username")
password=input("enter the password")
if username=="abc123":
  if password=="thrilesh777":
    print("valid username")
  else:
    print("invalid password")
else:
  print("invalid username")
# Out:
# enter the usernameabc777
# enter the passwordthrilesh7770
# invalid username

# %%
from traitlets.traitlets import NoDefaultSpecified
from typing_extensions import NoExtraItems
# sbi atm :  500, 200, 100
#      10000 -->
#      7000--> 15-500--> 7500+ 1-200+ 1-100
#      400--> 2-200
#      1000-- 500-2
# accept withdraw amount and print number of notes
# sample input:7900

# %%
#accept withdraw amount and print number of notes sample input:7800
withdraw=int(input("enter the withdraw amount"))
print(withdraw)
if withdraw%100==0:
  print("valid amount")
else:
  print("invalid amount")
# Out:
# enter the withdraw amount7800
# 7800
# valid amount

# %%
#accept withdraw amount and print number of notes sample input:7800
withdraw=int(input("enter the withdraw amount"))
print(withdraw)
if withdraw%100==0:
  print("valid amount")
else:
  print("invalid amount")

# %%
#accept withdraw amount and print number of notes sample input:7800
amount=int(input("enter the withdraw amount"))
if amount%100==0:
  if amount>=500:
    five=amount//500
    amount=amount-(five*500)
    print("500 ------",five)
  if amount>=200:
     two=amount//200
     amount=amount-(two*200)
     print("200------",two)
  if amount>=100:
     one=amount//100
     amount=amount-(one*100)
     print("100------",one)
else:
  print("please enter multiples of 100 only")
# Out:
# enter the withdraw amount8800
# 500 ------ 17
# 200------ 1
# 100------ 1
